# %%
import pandas as pd
data = pd.read_csv('data.csv', index_col=[0])
data = data.loc[:, ~data.columns.str.match('Unnamed')]
data
# Out:
#       Marital_status  Application_mode  Application_order  Course  Attendance
# 0                  1                17                  5     171           1  \
# 1                  1                15                  1    9254           1
# 2                  1                 1                  5    9070           1
# 3                  1                17                  2    9773           1
# 4                  2                39                  1    8014           0
# ...              ...               ...                ...     ...         ...
# 4419               1                 1                  6    9773           1
# 4420               1                 1                  2    9773           1
# 4421               1                 1                  1    9500           1
# 4422               1                 1                  1    9147           1
# 4423               1                10                  1    9773           1
#
# ...

# %%
display(data)
data.to_csv('data.csv')
data.to_csv('data.tsv', sep='\t', index=False)
# Out:
#       Marital_status  Application_mode  Application_order  Course  Attendance
# 0                  1                17                  5     171           1  \
# 1                  1                15                  1    9254           1
# 2                  1                 1                  5    9070           1
# 3                  1                17                  2    9773           1
# 4                  2                39                  1    8014           0
# ...              ...               ...                ...     ...         ...
# 4419               1                 1                  6    9773           1
# 4420               1                 1                  2    9773           1
# 4421               1                 1                  1    9500           1
# 4422               1                 1                  1    9147           1
# 4423               1                10                  1    9773           1
#
# ...

# %%
# JSON to CSV
import pandas as pd
df = pd.read_json('nightingale_rose.json')
df.to_csv('nightingale_rose.csv', index=False)

# %%
df = pd.read_csv('nightingale_rose.csv')
df
# Out:
#                          date  army_size  disease  wounds  other
# 0   1854-04-01 07:00:00+00:00       8571        1       0      5  \
# 1   1854-05-01 07:00:00+00:00      23333       12       0      9
# 2   1854-06-01 07:00:00+00:00      28333       11       0      6
# 3   1854-07-01 07:00:00+00:00      28722      359       0     23
# 4   1854-08-01 07:00:00+00:00      30246      828       1     30
# 5   1854-09-01 07:00:00+00:00      30290      788      81     70
# 6   1854-10-01 07:00:00+00:00      30643      503     132    128
# 7   1854-11-01 07:00:00+00:00      29736      844     287    106
# 8   1854-12-01 08:00:00+00:00      32779     1725     114    131
# 9   1855-01-01 08:00:00+00:00      32393     2761      83    324
# 10  1855-02-01 08:00:00+00:00      30919     2120      42    361
# 11  1855-03-01 08:00:00+00:00      30107     1205      32    172
# 12  1855-04-01 07:00:00+00:00      32252      477      48     57
# ...
